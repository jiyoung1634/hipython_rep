# %%
import main_func
# Out:
# kiosk
#
#         .================ooooooo
#  ___   ,'    \_________________________________
# /   /-/       /                   ////////////  ''--..._
# \___\-\       \                   \\\\\\\\\\\\  __..--'
#        `--------------------------''''''''''''''
#
# ╔════════════════════════════════════════╗
#              빵꾸똥꾸 문구야
#          에 오신 것을 환영합니다!💥
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  aaaa
# ...
#          [알림]❌ 잘못된 입력입니다.
#          [알림]✅ 다시 입력해주세요.
# ...
# 주문하실 제품 번호를 선택하세요:  80
# ...
#          [알림]❌ 잘못된 입력입니다.
#          [알림]✅ 다시 입력해주세요.
# ...
# 주문하실 제품 번호를 선택하세요:  5
# ...
#           고객님이 선택하신 제품은
#              공책 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  x
# ╔════════════════════════════════════════╗
#              빵꾸똥꾸 문구야
#          에 오신 것을 환영합니다!💥
# ...
