# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib
import seaborn

# %%
#한글폰트 검색
import matplotlib.font_manager as fm
for i in fm.fontManager.ttflist:
    if i.name.find('Gulim') != -1:
        print(i.name)
# Out:
# Gulim
# New Gulim

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Gulim'
rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt
plt.title('클래스와 오브젝트')
plt.xlabel('클래스')
plt.ylabel('오브젝트')
# Out:
# Text(0, 0.5, '오브젝트')

# %%
import seaborn as sns
anscombe = sns.load_dataset('anscombe')
anscombe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB

# %%
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
anscombe['dataset'].unique()   #범주형 변수
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
d1 = anscombe[anscombe['dataset']=='I']
d2 = anscombe[anscombe['dataset']=='II']
d3 = anscombe[anscombe['dataset']=='III']
d4 = anscombe[anscombe['dataset']=='IV']

# %%
d1.shape, d2.shape, d3.shape, d4.shape
# Out:
# ((11, 3), (11, 3), (11, 3), (11, 3))

# %%
d1.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000

# %%
d2.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031657
# min     4.000000   3.100000
# 25%     6.500000   6.695000
# 50%     9.000000   8.140000
# 75%    11.500000   8.950000
# max    14.000000   9.260000

# %%
d3.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500000
# std     3.316625   2.030424
# min     4.000000   5.390000
# 25%     6.500000   6.250000
# 50%     9.000000   7.110000
# 75%    11.500000   7.980000
# max    14.000000  12.740000

# %%
d4.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %%
plt.plot(d1['x'], d1['y'], 'o')

# %%
plt.plot(d2['x'], d2['y'], 'o')

# %%
plt.plot(d3['x'], d3['y'], 'o')

# %%
plt.plot(d4['x'], d4['y'], 'o')

# %%
dates = ['2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05']
prices = [100, 102, 101, 105, 103]

# %%
plt.figure(figsize=(10,6))
plt.title('Stock Prices Over 5Days')
plt.xlabel('Date')
plt.ylabel('dates')
plt.ylim(95,110)
plt.grid()
plt.plot(dates, prices, marker='o', label='Stock Price', color='blue')
plt.legend()

# %%
plt.subplot(1, 2, 1)
plt.plot(dates, prices, marker='o', color='green')
plt.title('Stock Prices - Subplot 1')
plt.xticks(rotation=40)   #x축 겹쳐보이니 각도만큼 돌려줌

plt.subplot(1, 2, 2)
plt.bar(dates, prices, color='orange')
plt.title('Stock Prices - Subplot 2')
plt.xticks(rotation=40)

plt.savefig('my_stock_price_char.png')

# %%
import numpy as np
data = np.random.randn(50).cumsum()
plt.plot(data)

# %%
#1변량 차트, 변수의 값을 요약 > 분포 분석 목적
plt.hist(np.random.randn(100), bins=20, color='k')
# Out:
# (array([ 1.,  0.,  1.,  1.,  5.,  5.,  8.,  8.,  9.,  7., 13., 13.,  8.,
#          7.,  4.,  3.,  4.,  1.,  0.,  2.]),
#  array([-3.09039891, -2.80189468, -2.51339045, -2.22488621, -1.93638198,
#         -1.64787775, -1.35937351, -1.07086928, -0.78236505, -0.49386081,
#         -0.20535658,  0.08314765,  0.37165189,  0.66015612,  0.94866036,
#          1.23716459,  1.52566882,  1.81417306,  2.10267729,  2.39118152,
#          2.67968576]),
#  <BarContainer object of 20 artists>)

# %%
plt.subplot(1, 3, 1)
plt.plot(dates, prices, marker='o', color='green')
plt.title('Stock Prices - Subplot 1')
plt.xticks(rotation=40)   #x축 겹쳐보이니 각도만큼 돌려줌

plt.subplot(1, 3, 2)
plt.bar(dates, prices, color='orange')
plt.title('Stock Prices - Subplot 2')
plt.xticks(rotation=40)

plt.subplot(1, 3, 3)
plt.hist(np.random.randn(100), bins=20, color='k')
# Out:
# (array([ 3.,  3.,  2.,  6.,  2.,  7.,  7.,  9.,  6.,  9., 11.,  6.,  8.,
#          3.,  2.,  7.,  3.,  2.,  2.,  2.]),
#  array([-1.90010537, -1.69321368, -1.48632198, -1.27943029, -1.07253859,
#         -0.8656469 , -0.6587552 , -0.45186351, -0.24497181, -0.03808011,
#          0.16881158,  0.37570328,  0.58259497,  0.78948667,  0.99637836,
#          1.20327006,  1.41016175,  1.61705345,  1.82394515,  2.03083684,
#          2.23772854]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# # 새로운 데이터셋
#
# Seaborn.tips 데이터셋

# %%
import seaborn as sns
tips_df = sns.load_dataset('tips')
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df['day']
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
#1변량 그래프 : 히스토그램
plt.hist(data=tips_df, x='total_bill', bins=20)
# Out:
# (array([ 1.,  6., 13., 29., 31., 37., 28., 23., 18., 13., 10.,  9.,  5.,
#          7.,  3.,  4.,  1.,  2.,  3.,  1.]),
#  array([ 3.07 ,  5.457,  7.844, 10.231, 12.618, 15.005, 17.392, 19.779,
#         22.166, 24.553, 26.94 , 29.327, 31.714, 34.101, 36.488, 38.875,
#         41.262, 43.649, 46.036, 48.423, 50.81 ]),
#  <BarContainer object of 20 artists>)

# %%
fig = plt.figure(figsize=(12,5))
axes1 = fig.add_subplot(1,2,1)   #total_bill
axes2 = fig.add_subplot(1,2,2)   #tips
axes1.hist(data=tips_df, x='total_bill', bins=20)
axes2.hist(data=tips_df, x='tip', bins=20)
plt.tight_layout()   #시각화한 그래프의 레이아웃을 자동으로 조정
plt.show()

# %%
#boxplot
fig = plt.figure(figsize=(12,5))
axes = fig.add_subplot(1,1,1)   
axes.boxplot(data=tips_df, x='total_bill')   #x값 하나 가지고 그렸으므로 1변량 차트
plt.show()

# %% [markdown]
# 위 박스플롯 차트에서 x축의 값 1은 우리가 따로 x축값 이름을 지정해주지 않았기 때문에 임의로 1로 출력된것이다.

# %%
fig = plt.figure(figsize=(12,5))
axes = fig.add_subplot(1,1,1)

axes.boxplot(
             x=[
                 tips_df[tips_df['sex'] == 'Female']['total_bill'],
                 tips_df[tips_df['sex'] == 'Male']['total_bill']
             ],
             labels=['Female', 'Male'])
plt.show()

# %%
fig = plt.figure(figsize=(12,5))
axes3 = fig.add_subplot(1,1,1)

axes3.boxplot(
    x=[
        tips_df[tips_df['day'] == 'Thur']['tip'],
        tips_df[tips_df['day'] == 'Fri']['tip'],
        tips_df[tips_df['day'] == 'Sat']['tip'],
        tips_df[tips_df['day'] == 'Sun']['tip']
    ],
    labels=['Thur', 'Fri', 'Sat', 'Sun']
)
plt.show()

# %%
fig = plt.figure(figsize=(12,5))
axes5 = fig.add_subplot(1,1,1)

axes5.boxplot(
    x=[
        tips_df[tips_df['day'] == 'Thur']['total_bill'],
        tips_df[tips_df['day'] == 'Fri']['total_bill'],
        tips_df[tips_df['day'] == 'Sat']['total_bill'],
        tips_df[tips_df['day'] == 'Sun']['total_bill']
    ],
    labels=['Thur', 'Fri', 'Sat', 'Sun']
)
plt.show()

# %%
fig = plt.figure(figsize=(12,5))
axes4 = fig.add_subplot(1,1,1)

axes4.boxplot(
    x=[
        tips_df[tips_df['time'] == 'Lunch']['tip'],
        tips_df[tips_df['time'] == 'Dinner']['tip'],
        
    ],
    labels=['Lunch', 'Dinner']
)
plt.title('시간별 팁')
plt.show()

# %%
fig = plt.figure(figsize=(12,5))
axes6 = fig.add_subplot(1,1,1)

axes6.boxplot(
    x=[
        tips_df[tips_df['smoker'] == 'No']['total_bill'],
        tips_df[tips_df['smoker'] == 'Yes']['total_bill'],
        
    ],
    labels=['No', 'Yes']
)
plt.show()

# %%
#2변량 그래프
#scatter, 산점도
fig = plt.figure()
axes7 = fig.add_subplot(1,1,1)

axes7.scatter(
    tips_df['total_bill'], tips_df['tip']
)
plt.show()

# %% [markdown]
# # 다변량 표현
# - 성별에 따라 팁 표현 -  색상
# - 값의 크기에 따라 점의 크기 조정

# %%
colors = {'Female' : 'red', 'Male': 'blue'}
fig = plt.figure()
axes7 = fig.add_subplot(1,1,1)

axes7.scatter(
    tips_df['total_bill'], tips_df['tip'],
    s=tips_df['size']**2*10,   #점이 클수록 size가 큰 것
    c=tips_df['sex'].map(colors)
)
plt.show()

# %%
#위 분포도에서 점의 크기를 tip의 금액
colors = {'Female' : '#ff00ad', 'Male': '#000000'}   #16진수 색상 표현
tips_df['tip_pct'] = tips_df['tip'] / tips_df['total_bill']   #'tip_pct' 변수 추가
fig = plt.figure()
axes8 = fig.add_subplot(1,1,1)

axes8.scatter(
    tips_df['total_bill'], tips_df['tip'],
    s=tips_df['tip_pct']*1000,   
    c=tips_df['sex'].map(colors)
)
plt.show()

# %%
#파이 차트 : 비율
#성별 비율 비교
sex_counts = tips_df['sex'].value_counts()   #빈도수 

fig = plt.figure()
axes9 = fig.add_subplot(1,1,1)

axes9.pie(   #파이차트
    sex_counts,
    colors=['blue', 'red'],
    labels=sex_counts.index,
    autopct='%1.1f%%',   #비율 값
    startangle=90
)
plt.show()

# %%
sex_counts.head()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
day_counts = tips_df['day'].value_counts()   #axes10
day_counts.head()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
smoker_counts = tips_df['smoker'].value_counts()   #axes11
smoker_counts.head()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
fig = plt.figure()
axes10 = fig.add_subplot(1,2,1)
axes10.pie(   
    day_counts,
    colors=["#ff1818", "#f17d0f", "#29d61a", "#4314ee"],
    labels=day_counts.index,
    autopct='%.2f%%'  
)
axes11 = fig.add_subplot(1,2,2)
axes11.pie(   
    smoker_counts,
    colors=["#2ada12", "#2782f8"],
    labels=smoker_counts.index,
    autopct='%.2f%%' 
)

plt.show()
